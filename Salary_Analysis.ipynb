# %% [markdown]
# "This is data analysis of salary of different programmer in pandas" by Pradip Budhathoki

# %%
import pandas as pd
import matplotlib as mat
df=pd.read_csv('ds_salaries.csv')

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %% [markdown]
# Shape of data frame.

# %%
df.shape         #it give the size of total data frame
# Out:
# (607, 12)

# %% [markdown]
# Information of data frame

# %%
df.info()         # it gives the detiels of data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# Mean salary of all people in USD

# %%
mean=sum(df['salary_in_usd'])/df.salary_in_usd.size
mean
# Out:
# 112297.86985172982

# %% [markdown]
# List the count of different job titles.

# %%
df.job_title.value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %% [markdown]
# Plot line graph on the basis of job title

# %%
df.job_title.value_counts().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# differenceate loc and iloc through example

# %%
df.loc[5:10,'work_year']
# Out:
# 5     2020
# 6     2020
# 7     2020
# 8     2020
# 9     2020
# 10    2020
# Name: work_year, dtype: int64

# %% [markdown]
# Hence loc give rows and columns of dataframe on the basis of labels or names

# %%
df.iloc[5:10,1]
# Out:
# 5    2020
# 6    2020
# 7    2020
# 8    2020
# 9    2020
# Name: work_year, dtype: int64

# %% [markdown]
# Hence iloc give rows and columns of dataframe on the basis of index or position

# %% [markdown]
# Filtering people with salaries greater then 100000 USD

# %%
filter_people=df.loc[df.salary_in_usd>=100000]
filter_people
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 4             4       2020               SE              FT
# 6             6       2020               SE              FT
# 8             8       2020               MI              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %% [markdown]
# Count the vlaue of group of peopel based on job title having salary greater then 100000USD

# %%
filter_people.job_title.value_counts()
# Out:
# Data Scientist                              78
# Data Engineer                               73
# Data Analyst                                42
# Machine Learning Engineer                   17
# Data Architect                              10
# Data Science Manager                        10
# Data Analytics Manager                       7
# Principal Data Scientist                     7
# Machine Learning Scientist                   7
# Director of Data Science                     7
# Research Scientist                           5
# Lead Data Engineer                           5
# Analytics Engineer                           4
# Head of Data                                 4
# Applied Data Scientist                       4
# Head of Data Science                         3
# Data Engineering Manager                     3
# Principal Data Engineer                      3
# Big Data Engineer                            2
# AI Scientist                                 2
# ...

# %% [markdown]
# Double filter the data frame on the basis of job title as Data Scientist and employee residence as us

# %%
df.loc[(df.job_title=='Data Scientist')&(df.employee_residence=='US')]
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 48           48       2020               MI              FT  Data Scientist
# 57           57       2020               MI              FT  Data Scientist
# 58           58       2020               SE              FT  Data Scientist
# 59           59       2020               MI              FT  Data Scientist
# 63           63       2020               SE              FT  Data Scientist
# ..          ...        ...              ...             ...             ...
# 592         592       2022               SE              FT  Data Scientist
# 593         593       2022               SE              FT  Data Scientist
# 596         596       2022               SE              FT  Data Scientist
# 598         598       2022               MI              FT  Data Scientist
# 599         599       2022               MI              FT  Data Scientist
#
# ...

# %% [markdown]
# Retrieve the list salaries in usd of double filtration data frame

# %%
list_salari=list(df[(df.job_title=='Data Scientist')&(df.employee_residence=='US')]['salary_in_usd'])
list_salari
# Out:
# [105000,
#  118000,
#  120000,
#  138350,
#  412000,
#  105000,
#  73000,
#  100000,
#  80000,
#  82500,
#  150000,
#  147000,
#  160000,
#  135000,
#  165000,
#  115000,
#  90000,
#  130000,
#  100000,
#  58000,
#  109000,
#  130000,
#  90000,
#  136620,
#  99360,
#  146000,
#  123000,
#  165220,
#  120160,
#  180000,
#  120000,
#  95550,
#  167000,
#  123000,
#  150000,
#  211500,
#  138600,
#  170000,
#  123000,
#  215300,
#  158200,
#  180000,
#  260000,
#  180000,
#  80000,
#  140400,
#  215300,
#  104890,
#  140000,
#  220000,
#  140000,
#  185100,
#  200000,
#  120000,
#  230000,
#  165000,
#  135000,
#  78000,
#  141300,
#  102100,
#  205300,
#  140400,
#  176000,
#  144000,
#  205300,
#  140400,
#  140000,
#  210000,
#  140000,
#  210000,
#  140000,
#  210000,
#  140000,
#  230000,
#  150000,
#  210000,
#  160000,
#  130000]
